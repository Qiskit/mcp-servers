# %% [markdown]
# # LangChain Agent with Qiskit Docs MCP Server
#
# This notebook demonstrates how to create an AI agent using LangChain that connects to the **qiskit-docs-mcp-server** via the Model Context Protocol (MCP).
#
# The agent uses the documentation MCP server to:
# - Retrieve SDK module lists and documentation pages
# - Answer factual questions by quoting and citing Qiskit docs (RAG mode)
# - Provide concise excerpts, example snippets, and resource URIs
#
# ## Architecture
#
# ```
# ┌─────────────┐     MCP Server       ┌──────────────────────────────────┐
# │  LangChain  │ ◄──────────────────► │      qiskit-docs-mcp-server       │
# │    Agent    │                      │                                  │
# └─────────────┘                      │  ┌────────────────────────────┐  │
#                                      │  │  Qiskit Documentation      │  │
#                                      │  │  SDK Module References     │  │
#                                      │  └────────────────────────────┘  │
#                                      │               │                  │
#                                      └───────────────│──────────────────┘
#                                                      ▼
#                                             ┌─────────────────┐
#                                             │   Qiskit Docs   │
#                                             │   Repository    │
#                                             └─────────────────┘
# ```

# %% [markdown]
# ## Setup
#
# ### 1. Install Dependencies
#
# Run these commands in your terminal:
#
# ```bash
# # Install the MCP server with examples dependencies
# pip install qiskit-docs-mcp-server[examples]
#
# # Install your preferred LLM provider (choose one):
# pip install langchain-openai       # For OpenAI
# pip install langchain-anthropic    # For Anthropic Claude
# pip install langchain-google-genai # For Google Gemini
# pip install langchain-ollama       # For local Ollama
# pip install langchain-ibm          # For IBM Watsonx
# ```

# %% [markdown]
# ### 2. Configure Environment Variables
#
# Set your LLM provider API key for the agent.
#
# You can either:
# - Set them in a `.env` file in this directory
# - Set them as environment variables
# - Enter them in the cell below

# %%
import os

from dotenv import load_dotenv

# LangChain imports
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain_mcp_adapters.tools import load_mcp_tools


# Load from .env file if it exists
load_dotenv()  # looks for .env in current working directory


# Set your LLM provider API key (uncomment the one you're using):
# os.environ["OPENAI_API_KEY"] = "your-openai-api-key"
# os.environ["ANTHROPIC_API_KEY"] = "your-anthropic-api-key"
# os.environ["GOOGLE_API_KEY"] = "your-google-api-key"


# Verify configuration
print("Configuration status:")
print(f"  LLM Provider Key: {'✓ Set' if any(os.getenv(k) for k in ['OPENAI_API_KEY', 'ANTHROPIC_API_KEY', 'GOOGLE_API_KEY']) else '✗ Not set'}")

# %% [markdown]
# ## Choose Your LLM Provider
#
# Run **one** of the following cells based on your preferred LLM provider:

# %%
# Option 1: OpenAI
from langchain_openai import ChatOpenAI


llm = ChatOpenAI(model="gpt-4o", temperature=0)
print("Using OpenAI GPT-4o")

# %%
# Option 2: Anthropic Claude
from langchain_anthropic import ChatAnthropic


llm = ChatAnthropic(model="claude-sonnet-4-20250514", temperature=0)
print("Using Anthropic Claude Sonnet")

# %%
# Option 3: Google Gemini
from langchain_google_genai import ChatGoogleGenerativeAI


llm = ChatGoogleGenerativeAI(model="gemini-2.5-pro", temperature=0)
print("Using Google Gemini Pro")

# %%
# Option 4: Local Ollama (no API key needed)
from langchain_ollama import ChatOllama


llm = ChatOllama(model="llama3.2", temperature=0)
print("Using local Ollama with Llama 3.2")

# %%
# Option 5: IBM Watsonx
from langchain_ibm import ChatWatsonx


llm = ChatWatsonx(
    model_id="ibm/granite-3-8b-instruct",
    url=os.getenv("WATSONX_URL", "https://us-south.ml.cloud.ibm.com"),
    project_id=os.getenv("WATSONX_PROJECT_ID"),
    params={"temperature": 0, "max_tokens": 4096},
)
print("Using IBM Watsonx Granite")
# Out:
# Using IBM Watsonx Granite
# /Users/va/blue/tools/miniforge3/envs/code-assistant-mcp/lib/python3.12/site-packages/ibm_watsonx_ai/foundation_models/utils/utils.py:429: LifecycleWarning: Model 'ibm/granite-3-8b-instruct' is in deprecated state from 2025-11-24 until 2026-02-22. IDs of alternative models: ibm/granite-4-h-small. Further details: https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/fm-model-lifecycle.html?context=wx&audience=wdp
#   warn(model_state_warning, category=LifecycleWarning)

# %% [markdown]
# ## Define the System Prompt
#
# This prompt tells the agent what it can do and how to behave:

# %%
SYSTEM_PROMPT = """You are a knowledgeable Qiskit documentation assistant with access to the
qiskit-docs-mcp-server through the MCP server.

You can help users:
- Retrieve SDK module lists and documentation pages (list_sdk_modules, get_module_docs)
- Answer factual questions by quoting and citing Qiskit documentation
- Provide concise excerpts, example snippets, and resource URIs for follow-up

When answering:
- Prefer exact quotes or short excerpts from documentation and include the resource URI
- If multiple sources apply, summarize and list the sources used
- For code examples, indicate the documented origin and recommend how to run them
- If a topic is not found, explain the search steps and suggest related documentation pages
"""

# %% [markdown]
# ## Create the MCP Client
#
# This configures the connection to the qiskit-docs-mcp-server:

# %%
import sys
import os

def get_mcp_client():
    base_path = "/home/luke/Desktop/mcp-servers/qiskit-docs-mcp-server"
    venv_python = os.path.join(base_path, ".venv/bin/python")
    src_path = os.path.join(base_path, "src")

    return MultiServerMCPClient(
        {
            "qiskit-docs": {
                "transport": "stdio",
                "command": "qiskit-docs-mcp-server",
                "args": [],
                "env": {},
            }
        }
    )

# %% [markdown]
# ## Create the Agent
#
# Now we'll create a function that sets up the agent with a persistent MCP session.
#
# Using a persistent session is important because it:
# - Keeps a single MCP server process running
# - Reuses the documentation data connection
# - Makes tool calls much faster

# %%
async def create_agent_with_session(session):
    """Create a LangChain agent using an existing MCP session."""
    # Load tools from the existing session
    tools = await load_mcp_tools(session)
    print(f"Loaded {len(tools)} tools from MCP server:")
    for tool in tools:
        print(f"  - {tool.name}")

    # Create the agent using LangChain's create_agent
    agent = create_agent(llm, tools, system_prompt=SYSTEM_PROMPT)
    return agent

# %% [markdown]
# ## Helper Function to Run Queries
#
# This function sends a query to the agent and returns the response:

# %%
async def ask_agent(agent, query: str) -> str:
    """Send a query to the agent and return the response."""
    result = await agent.ainvoke({"messages": [HumanMessage(content=query)]})
    messages = result.get("messages", [])
    if messages:
        return messages[-1].content
    return "No response generated."

# %% [markdown]
# ## Run the Agent
#
# Now let's create the agent and ask it some questions!
#
# The following cell starts the MCP server, creates the agent, and keeps the session open for multiple queries:

# %%
# Create MCP client and start a persistent session
mcp_client = get_mcp_client()

print("Starting MCP server and creating agent...")
print("(This may take a few seconds on first run)\n")
# Out:
# Starting MCP server and creating agent...
# (This may take a few seconds on first run)

# %% [markdown]
# ### Example 1: List Qiskit SDK Modules
#
# Let's ask the agent to retrieve the list of available SDK modules:

# %%
async with mcp_client.session("qiskit-docs") as session:
    agent = await create_agent_with_session(session)

    response = await ask_agent(agent, "What are the available SDK modules in Qiskit?")
    print(response)
# Out:
# Loaded 3 tools from MCP server:
#   - get_sdk_module_docs
#   - get_guide
#   - search_docs
# To retrieve the list of available SDK modules in Qiskit, you can use the `list_sdk_modules` function. However, as an assistant, I can provide you with the list directly:
#
# 1. `circuit`
# 2. `primitives`
# 3. `transpiler`
# 4. `quantum_info`
# 5. `aqua`
# 6. `ignis`
# 7. `magma`
# 8. `opflow`
# 9. `qiskit`
# 10. `qiskit-terra`
# 11. `qiskit-aer`
# 12. `qiskit-ignis`
# 13. `qiskit-aqua`
# 14. `qiskit-magma`
# 15. `qiskit-opflow`
#
# For detailed documentation on each module, you can use the `get_sdk_module_docs` function. For example, to get the documentation for the `circuit` module, you would call `get_sdk_module_docs('circuit')`.
#
# Resource: Qiskit SDK Modules - https://qiskit.org/documentation/apidoc/modules.html

# %% [markdown]
# ### Example 2: Get Documentation About Quantum Circuits
#
# Retrieve documentation on a specific topic:

# %%
async with mcp_client.session("qiskit-docs") as session:
    agent = await create_agent_with_session(session)

    response = await ask_agent(agent, "Show me documentation about quantum circuits and how to create them")
    print(response)
# Out:
# Loaded 3 tools from MCP server:
#   - get_sdk_module_docs
#   - get_guide
#   - search_docs
# To learn about quantum circuits and how to create them in Qiskit, you can refer to the following documentation:
#
# 1. **Qiskit Textbook: Quantum Circuits**
#    - Resource URI: <https://qiskit.org/textbook/ch-algorithms/quantum-circuits.html>
#    - Excerpt: "Quantum circuits are a way to visualize and build quantum algorithms. They consist of a sequence of quantum gates, measurements, and classical control operations."
#
# 2. **Qiskit Circuit Library**
#    - Resource URI: <https://qiskit.org/documentation/apidoc/circuit_library.html>
#    - Excerpt: "Qiskit provides a library of pre-defined quantum circuits for common use cases, such as state preparation, oracles, and more."
#
# 3. **Creating Quantum Circuits in Qiskit**
#    - Resource URI: <https://qiskit.org/documentation/apidoc/circuit.html#creating-quantum-circuits>
#    - Excerpt: "To create a quantum circuit in Qiskit, you can use the `QuantumCircuit` class from the `qiskit.circuit` module."
#
# Here's a simple example of creating a quantum circuit with one qubit and one classical bit:
#
# ```python
# from qiskit import QuantumCircuit
#
# # Create a Quantum Circuit acting on a quantum register of one qubit
# circ = QuantumCircuit(1)
#
# # Add a H gate on qubit 0
# circ.h(0)
#
# # Visualize the circuit
# print(circ)
# ```
#
# You can run this code in a Qiskit environment, such as a Jupyter notebook or a Qiskit script.
#
# For more information on quantum circuits and their components, you can refer to the Qiskit Textbook chapter on Quantum Circuits (<https://qiskit.org/textbook/ch-algorithms/quantum-circuits.html>).

# %% [markdown]
# ### Example 3: Learn About VQE
#
# Get documentation about Variational Quantum Eigensolver:

# %%
async with mcp_client.session("qiskit-docs") as session:
    agent = await create_agent_with_session(session)

    response = await ask_agent(agent, "What is VQE and how do I implement it in Qiskit?")
    print(response)
# Out:
# Loaded 3 tools from MCP server:
#   - get_sdk_module_docs
#   - get_guide
#   - search_docs
# The Variational Quantum Eigensolver (VQE) is a hybrid quantum-classical algorithm used for finding the ground state energy of a given Hamiltonian. It is particularly useful in quantum chemistry for estimating the electronic structure of molecules.
#
# To implement VQE in Qiskit, follow these steps:
#
# 1. Import the necessary modules:
#
# ```python
# from qiskit import Aer, QuantumCircuit
# from qiskit.circuit.library import TwoLocal
# from qiskit.algorithms import VQE
# from qiskit.algorithms.optimizers import COBYLA
# from qiskit.aqua.operators import Z2Symmetries
# ```
#
# 2. Define the Hamiltonian for the molecule of interest. For this example, let's use a simple H2 molecule:
#
# ```python
# from qiskit.aqua.operators import Z2Symmetries
# from qiskit.chemistry.drivers import PySCFDriver
# from qiskit.chemistry import FermionicOperator
#
# driver = PySCFDriver(atom='H .0 .0 -0.5; H .0 .0 0.5', unit=UnitsType.ANGSTROM, charge=0, spin=0, basis='sto3g')
# molecule = driver.run()
# ferOp = FermionicOperator(h1=molecule.one_body_integrals, h2=molecule.two_body_integrals)
#
# # Apply Z2 symmetries
# symmetry_symm = Z2Symmetries(num_particles=molecule.num_alpha + molecule.num_beta, z2_symmetries=molecule.z2_symmetries)
# ferOp = symmetry_symm.get_z2_symmetries_operator(ferOp)
# ```
#
# 3. Create a parameterized quantum circuit:
#
# ```python
# ansatz = TwoLocal(rotation_blocks='ry', entanglement_blocks='cz')
# vqe = VQE(ansatz, optimizer=COBYLA(), quantum_instance=Aer.get_backend('statevector_simulator'))
# ```
#
# 4. Run the VQE algorithm:
#
# ```python
# result = vqe.run(ferOp)
# ```
#
# 5. Retrieve the ground state energy:
#
# ```python
# print("Ground state energy:", result.eigenvalue)
# ```
#
# For more information, refer to the Qiskit Textbook's VQE section:
#
# - [VQE in Qiskit Textbook](https://qiskit.org/textbook/ch-algorithms/vqe.html)
#
# And the Qiskit documentation on VQE:
#
# - [VQE in Qiskit Documentation](https://qiskit.org/documentation/stubs/qiskit.algorithms.VQE.html)

# %% [markdown]
# ### Example 4: Understand the Qiskit Transpiler
#
# Get documentation on circuit transpilation:

# %%
async with mcp_client.session("qiskit-docs") as session:
    agent = await create_agent_with_session(session)

    response = await ask_agent(agent, "Explain the Qiskit transpiler and how it works")
    print(response)
# Out:
# Loaded 3 tools from MCP server:
#   - get_sdk_module_docs
#   - get_guide
#   - search_docs
# The Qiskit transpiler is a component of the Qiskit framework that optimizes quantum circuits for execution on real quantum devices. It takes a quantum circuit as input and transforms it into an equivalent circuit that can be executed on a target quantum device, considering the device's constraints and noise characteristics.
#
# The transpiler works by applying a series of optimization passes to the input circuit. These passes can include:
#
# 1. Basis translation: Converting gates in the circuit to a different gate set that is natively supported by the target device.
# 2. Optimization: Reducing the circuit depth and number of gates to minimize execution time and improve fidelity.
# 3. Layout: Mapping the logical qubits in the circuit to the physical qubits of the target device.
# 4. Scheduling: Determining the optimal order in which to execute the gates on the target device.
# 5. Noise adaptation: Adapting the circuit to account for the noise characteristics of the target device.
#
# The transpiler can be customized by selecting specific optimization passes or creating custom passes. It is typically invoked using the `transpile()` function in Qiskit.
#
# For more information, refer to the Qiskit documentation on the transpiler:
#
# - [Qiskit Textbook: Transpiler](https://qiskit.org/textbook/ch-quantum-hardware/transpiler.html)
# - [Qiskit Documentation: Transpiler](https://qiskit.org/documentation/apidoc/transpiler.html)
#
# Resource URIs:
# - Qiskit Textbook: <https://qiskit.org/textbook/ch-quantum-hardware/transpiler.html>
# - Qiskit Documentation: <https://qiskit.org/documentation/apidoc/transpiler.html>

# %% [markdown]
# ### Example 5: Interactive Chat
#
# Run this cell to have an interactive conversation with the documentation assistant:

# %%
async with mcp_client.session("qiskit-docs") as session:
    agent = await create_agent_with_session(session)
    print("Agent ready! Type your questions below.")
    print("Enter 'quit' to stop.\n")

    while True:
        try:
            query = input("You: ").strip()
            if not query:
                continue
            if query.lower() in ["quit", "exit", "q"]:
                print("Goodbye!")
                break

            response = await ask_agent(agent, query)
            print(f"\nAssistant: {response}\n")
        except KeyboardInterrupt:
            print("\nGoodbye!")
            break

# %% [markdown]
# ## Custom Query Cell
#
# Use this cell to ask the agent any documentation question:

# %%
# Enter your question here:
MY_QUESTION = "What are the best practices for writing efficient Qiskit code?"

async with mcp_client.session("qiskit-docs") as session:
    agent = await create_agent_with_session(session)
    response = await ask_agent(agent, MY_QUESTION)
    print(response)

# %% [markdown]
# ## Available Tools
#
# The agent has access to these tools provided by the MCP server:
#
# | Tool | Description |
# |------|-------------|
# | `list_sdk_modules` | Retrieve list of available Qiskit SDK modules |
# | `get_module_docs` | Get detailed documentation for a specific module |
# | `search_docs` | Search documentation by keywords and topics |

# %% [markdown]
# ## Troubleshooting
#
# ### MCP server not found?
# Make sure `qiskit-docs-mcp-server` is installed and in your Python path. Run:
# ```bash
# pip install qiskit-docs-mcp-server[examples]
# ```
#
# ### Import errors?
# Ensure all dependencies are installed:
# ```bash
# pip install langchain langchain-mcp-adapters python-dotenv
# ```
#
# ### Connection issues?
# - Verify the MCP server is running properly
# - Check that the server command `qiskit-docs-mcp-server` is accessible from your shell
# - Try running in a fresh terminal session
